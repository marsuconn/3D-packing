# %%
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(5)

# %%
n = 10
arms = np.random.rand(n)
eps = 0.1 #probability of exploration action

# %%
arms
# Out:
# array([0.22199317, 0.87073231, 0.20671916, 0.91861091, 0.48841119,
#        0.61174386, 0.76590786, 0.51841799, 0.2968005 , 0.18772123])

# %%
def reward(prob):
    reward = 0
    for i in range(10):
        if random.random() < prob:
            reward += 1
    return reward

# %%
av = np.array([np.random.randint(0,(n+1)), 0]).reshape(1,2) #av = action-value

# %%
#greedy method to select best arm based on memory array
def bestArm(a):
    bestArm = 0 #default to 0
    bestMean = 0
    for u in a:
        avg = np.mean(a[np.where(a[:,0] == u[0])][:, 1]) #calculate mean reward for each action
        if bestMean < avg:
            bestMean = avg
            bestArm = u[0]
    return bestArm

# %%
np.array([3,0])
# Out:
# array([3, 0])

# %%
plt.xlabel("Number of times played")
plt.ylabel("Average Reward")
for i in range(1000):
    if random.random() > eps: #greedy exploitation action
        choice = bestArm(av)
        thisAV = np.array([[choice, reward(arms[choice])]])
        av = np.concatenate((av, thisAV), axis=0)
    else: #exploration action
        choice = np.where(arms == np.random.choice(arms))[0][0]
        thisAV = np.array([[choice, reward(arms[choice])]]) #choice, reward
        av = np.concatenate((av, thisAV), axis=0) #add to our action-value memory array
    #calculate the mean reward
    runningMean = np.mean(av[:,1])
    plt.scatter(i, runningMean)

# %%
IU=[3,9]
IUU=[4,8]

# %%
J=[4,3,8,9]

# %%
IU
# Out:
# [1, 2, 3, 4, 5]

# %%
IUU=[6,7]

# %%
J=IU+IUU
J=[]

# %%
IU
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
sorted(J,key=I.index)
# Out:
# []

# %%
sorted(J, key={e:i for i,e in enumerate(I)}.get)
# Out:
# []

# %%
I=[1,4, 4, 7,8,9]

# %%
IUU=[]

# %%
for i in I:

    print('checking :', i)
    print(I)
    if i%2==0:
        IUU.append(i)
        I.remove(i)
        print("I:", I)
# Out:
# checking : 1
# [1, 4, 4, 7, 8, 9]
# checking : 4
# [1, 4, 4, 7, 8, 9]
# I: [1, 4, 7, 8, 9]
# checking : 7
# [1, 4, 7, 8, 9]
# checking : 8
# [1, 4, 7, 8, 9]
# I: [1, 4, 7, 9]

# %%
IUU
# Out:
# [4, 8]

# %%
I
# Out:
# [1, 3, 7, 9]

# %%
I=[1,4, 7, 6, 7,8,9]
IU=I

# %%
while IU !=[]:
    print ('I: ',I)
    print('IU :' ,IU)
    for i in I:
        print(i)
        if i*i<=36:
            IU.remove(i)
    if i>=9:
        break
# Out:
# I:  [1, 4, 7, 6, 7, 8, 9]
# IU : [1, 4, 7, 6, 7, 8, 9]
# 1
# 7
# 6
# 8
# 9

# %%
import numpy as np
input_data=np.array([2,3])
weights={'node_0':np.array([1,1]),
          'node_1':np.array([-1,1]),
         'output':np.array([2-1])}

node_0_value=(input_data*weights['node_0']).sum()
node_1_value=input_data@weights['node_1']

# %%
node_0_value=(input_data*weights['node_0']).sum()

# %%
node_1_value
# Out:
# 1

# %%
input_data*weights['node_0']
# Out:
# array([2, 3])

# %%
input_data@weights['node_0']
# Out:
# 5

# %%
weights['node_0']
# Out:
# array([1, 1])

# %%
input_data
# Out:
# array([2, 3])

# %%
a = np.array([[1,2],[3,4]])
b = np.array([[11,12],[13,14]])

# %%
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
b
# Out:
# array([[11, 12],
#        [13, 14]])

# %%
a*b
# Out:
# array([[11, 24],
#        [39, 56]])

# %%
np.dot(a,b)
# Out:
# array([[37, 40],
#        [85, 92]])

# %%
def calculateFibonacci(n):
  memoize = [-1 for x in range(n+1)]
  return calculateFibonacciRecur(memoize, n)


def calculateFibonacciRecur(memoize, n):
  if n < 2:
    return n

  # if we have already solved this subproblem, simply return the result from the cache
  if memoize[n] >= 0:
    return memoize[n]

  memoize[n] = calculateFibonacciRecur(
    memoize, n - 1) + calculateFibonacciRecur(memoize, n - 2)
  return memoize[n]


def main():
  print("5th Fibonacci is ---> " + str(calculateFibonacci(5)))
  print("6th Fibonacci is ---> " + str(calculateFibonacci(6)))
  print("7th Fibonacci is ---> " + str(calculateFibonacci(7)))


main()
# Out:
# array([3, 4, 5])

# %%
def fib(n):
    if n<2:
        return n
    return fib(n-1)+fib(n-2)

# %%
def fib(n):
    memoise=[-1 for x in range(n+1)]
    return fibrecur(memoise,n)

def fibrecur(memoise, n):
    if n<2:
        return n
    if memoise[n]>=0:
        return memoise[0]

    memoise[n]=fibrecur(memoise,n-1)+fibrecur(memois,n-2)
    return memoise[n]
# Out:
# 1

# %%
n=3

# %%
m=[-1 for x in range(n+1)]

# %%
IP
# Out:
# []

# %%
I= [1,2,6,3,4,9,7, 5,6]
IP=[]

# %%
IU=I.copy()
IUU=[]
I_retry=[]

while IU!=[]:

    for i in IU:
        if i*i>50:
            IUU.append(i)
        else:
            if i+5>14:
                I_retry.append(i)
            else:
                IP.append(i)

    if I_retry!=[] and set(I_retry)!=set(IU):
        IU=[x for x in I_retry]
        print('going back to while')
        continue
    if I_retry==0 or set(I_retry)==set(IU):
        IU=[x for x in I if x not in IP]
        print('stopping while')
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\ASHRAF~1.RAH\AppData\Local\Temp/ipykernel_23364/3552933076.py in <module>
#      12                 I_retry.append(i)
#      13             else:
# ---> 14                 IP.append(i)
#      15
#      16     if I_retry!=[] and set(I_retry)!=set(IU):
#
# KeyboardInterrupt:

# %%
l={}
# Out:
# [1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
#  5,
#  6,
#  1,
#  2,
#  6,
#  3,
#  4,
#  7,
# ...

# %%
set(I)
